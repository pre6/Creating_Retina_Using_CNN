# %% [markdown]
# # Now Cone Cells

# %% [markdown]
# <h1>The Cone cell absorption spectrum</h1>
#
# ![image.png](attachment:fb16720a-b2ef-4ee6-8895-0dbe2b37f29e.png)
#
# ![image.png](attachment:de9d739f-4a42-45a3-8d8e-3ab01ffebe81.png)
#
# ref: 10.3390/molecules28155829

# %% [markdown]
# <h1> Make these functions</h1>
#
# Similar to Rod cells I think we can use the Gaussian funtion to approximate this graph
